# %%
import time
import requests
import pandas as pd
import signaturehelper
import json

# %%
def get_header(method, uri, api_key, secret_key, customer_id):
    timestamp = str(round(time.time() * 1000))
    signature = signaturehelper.Signature.generate(timestamp, method, uri, SECRET_KEY)
    return {'Content-Type': 'application/json; charset=UTF-8', 'X-Timestamp': timestamp, 'X-API-KEY': API_KEY, 'X-Customer': str(CUSTOMER_ID), 'X-Signature': signature}

# %%
BASE_URL = 'https://api.searchad.naver.com'
API_KEY = '0100000000cdaf66a53281a8739b896194c331fa06e177a79c4f93f0b23567b88a38033c33'
SECRET_KEY = 'AQAAAADNr2alMoGoc5uJYZTDMfoGlQMRCzZhw98TXB56xorVew=='
CUSTOMER_ID = '1106674'

# %%
uri = '/ncc/adgroups'
method = 'GET'

response = requests.get(BASE_URL + uri, headers = get_header(method, uri, API_KEY, SECRET_KEY, CUSTOMER_ID))

#print(response)
#print(response.json())
adgrp_df = pd.DataFrame(response.json())
display(adgrp_df)
# Out:
#                    nccAdgroupId  customerId                nccCampaignId  \
# 0   grp-a001-01-000000028803530     1106674  cmp-a001-01-000000005687696
# 1   grp-a001-01-000000028818215     1106674  cmp-a001-01-000000005721990
# 2   grp-a001-01-000000028818222     1106674  cmp-a001-01-000000005721990
# 3   grp-a001-01-000000039893057     1106674  cmp-a001-01-000000005687696
# 4   grp-a001-01-000000041479223     1106674  cmp-a001-01-000000007936717
# 5   grp-a001-01-000000045784564     1106674  cmp-a001-01-000000005687696
# 6   grp-a001-01-000000045784565     1106674  cmp-a001-01-000000005687696
# 7   grp-a001-01-000000047200395     1106674  cmp-a001-01-000000008939670
# 8   grp-a001-01-000000047200426     1106674  cmp-a001-01-000000008939670
# 9   grp-a001-01-000000058135714     1106674  cmp-a001-01-000000005687696
# 10  grp-a001-01-000000058135740     1106674  cmp-a001-01-000000008939670
# 11  grp-a001-01-000000058940540     1106674  cmp-a001-01-000000005687696
# ...

# %%
uri = '/ncc/keywords'
method = 'GET'

response = requests.get(BASE_URL + uri, params={'nccAdgroupId': "grp-a001-01-000000039893057"}, headers=get_header(method, uri, API_KEY, SECRET_KEY, CUSTOMER_ID))
kwd_df = pd.DataFrame(response.json())
display(kwd_df)
# Out:
#                     nccKeywordId       keyword  customerId  \
# 0    nkw-a001-01-000005939582767       온라인명도소송     1106674
# 1    nkw-a001-01-000005939582768        사전명도소송     1106674
# 2    nkw-a001-01-000005939582769   명도소송부동산법률센터     1106674
# 3    nkw-a001-01-000005939582770        법원명도소송     1106674
# 4    nkw-a001-01-000005939582771       법무사명도소송     1106674
# ..                           ...           ...         ...
# 118  nkw-a001-01-000007707363253     부동산명도소송절차     1106674
# 119  nkw-a001-01-000007707363254  세입자명도소송시필요서류     1106674
# 120  nkw-a001-01-000007707363255       명도소송승소후     1106674
# 121  nkw-a001-01-000007707363256       아파트강제집행     1106674
# 122  nkw-a001-01-000007707363257     부동산강제집행절차     1106674
#
#                     nccAdgroupId                nccCampaignId  userLock  \
# 0    grp-a001-01-000000039893057  cmp-a001-01-000000005687696     False
# 1    grp-a001-01-000000039893057  cmp-a001-01-000000005687696     False
# ...

# %%
uri = '/stats'
method = 'GET'
kwd_ids = kwd_df['nccKeywordId'].tolist()
r = requests.get(BASE_URL + uri, params={'ids': kwd_ids, 'fields': '["clkCnt","impCnt", "avgRnk", "ccnt", "ror"]',
                                         'timeRange': '{"since":"2025-10-01","until":"2025-12-26"}'},
                                         headers=get_header(method, uri, API_KEY, SECRET_KEY, CUSTOMER_ID))

print(f"Status Code: {r.status_code}")
res_data = r.json()



# 결과 출력
if 'data' in res_data:
    stat_df = pd.DataFrame(res_data['data'])
    #sorted_df = stat_df.sort_values(by='ror', ascending=False)
    #display(sorted_df)
else:
    print("데이터가 없습니다:", res_data)

merged_df = pd.merge(stat_df, kwd_df, left_on='id', right_on='nccKeywordId', how='left')
res_df = merged_df[['keyword','nccKeywordId','bidAmt','clkCnt','impCnt','avgRnk','ccnt','ror','nccQi']]

res_data = res_df.to_dict(orient='records')

display(res_df)
# Out:
# Status Code: 200
#       keyword                 nccKeywordId  bidAmt  clkCnt  impCnt  avgRnk  \
# 0     온라인명도소송  nkw-a001-01-000005939582767    3000       0       7     1.7
# 1      사전명도소송  nkw-a001-01-000005939582768    3000       0       2     1.0
# 2      법원명도소송  nkw-a001-01-000005939582770    3000       0       9     1.2
# 3     법무사명도소송  nkw-a001-01-000005939582771   14400       3      24     2.2
# 4    법도명도소송센터  nkw-a001-01-000005939582772    3000       0       1     1.0
# ..        ...                          ...     ...     ...     ...     ...
# 90   명도소송변호사비  nkw-a001-01-000007707363251      70       0       3     3.0
# 91  부동산명도소송절차  nkw-a001-01-000007707363253      70       0       6     1.2
# 92    명도소송승소후  nkw-a001-01-000007707363255      70       0      20     1.2
# 93    아파트강제집행  nkw-a001-01-000007707363256      70       0       6     1.3
# 94  부동산강제집행절차  nkw-a001-01-000007707363257      70       1      89     1.5
#
#     ccnt  ror           nccQi
# ...

# %%
# !pip install -q -U google-genai

# %%
from google import genai
from google.genai import types
import json

API_KEY = "AIzaSyByau6ay2-ej6TIQHvbkaN8nHj3fMIVfbo"
client = genai.Client(api_key = API_KEY)

#res_data

prompt = f"""
당신은 네이버 검색광고 입찰가 최적화 AI Agent입니다.

# Role: 네이버 검색광고 자동 입찰가 최적화 엔진
당신은 입력된 성과 데이터를 분석하여 즉시 적용 가능한 '최종 변경 입찰가'를 결정하는 확정형 실행 엔진입니다. 모호한 제안 대신, 아래의 수치적 로직(Step-by-Step)에 따라 계산된 최종 금액을 도출하십시오.

# Input Data (JSON):
{json.dumps(res_data, ensure_ascii=False, indent = 2)}

#데이터 정보:
-bidAmt: 현재 입찰가
-impCnt: 노출수
-clkCnt: 클릭수
-avgRnk: 평균 노출 순위
-ccnt: 전환수
-ror: ROAS (광고 수익률)
-nccQi: 품질지수

# Target KPIs:
- Primary: ROAS 300% 이상 유지
- Secondary: 효율 구간 내 평균 노출 순위 2.0 ~ 5.0위 유지
- 입찰가 조정 제한: 현재 입찰가 대비 최대 ±20% 이내 (급격한 순위 변동 방지)
- 최소 입찰가: 70원 (네이버 기본)
- 최대 입찰가: 60,000원

# Bid Adjustment Logic (수학적 알고리즘):

1. **성과 기반 필터링 (ROAS)([클릭수 > 0]일 때 적용)**
   - ROAS ≥ 300%: '우수' -> 현재가 대비 10% 인상 (최대 입찰가 제한 내, 평균순위 <= 2.0이면 현재가 유지)
   - 150% ≤ ROAS < 300%: '유지' -> 현재가 유지 (평균 순위가 6위 이하라면 10% 인상)
   - 100% ≤ ROAS < 150%: '주의' -> 현재가 대비 10% 인하
   - ROAS < 100%: '저효율' -> 현재가 대비 20% 인하 (최소 입찰가 제한 내)

2. **노출 최적화 (Avg Rank & Imps)**
   - [ROAS 우수]인데 [평균 순위 > 5.0]: 노출 부족 상태. 입찰가 +15% (공격적 확보)
   - [ROAS 저효율]인데 [평균 순위 < 2.0]: 과도한 비용 지출 상태. 입찰가 -20% (효율 방어)
   - [클릭수 > 20]인데 [전환수 = 0]: CVR 불량. 즉시 입찰가 30% 인하 (손절 구간)
   - [노출수 > 0]이고 [클릭수 = 0]인데 [평균순위 > 5.0]이면 입찰가 +20% (노출 기회 증가)
   - 노출수(impCnt) = 0 이면 입찰가 유지

3. **품질지수(QS) 가중치 반영**
   - QS 6~7: 계산된 인상폭의 1.5배, 계산된 인하폭의 0.7배 적용 (효율 극대화)
   - QS 1~3: 인상 금지. 모든 인상 로직을 '유지'로 변경하고 인하 로직만 적용

# Constraints & Rules:
- 모든 최종 입찰가는 네이버 입찰 단위(10원 단위)로 올림/내림 처리할 것.
- 최소 입찰가는 70원, 최대 입찰가는 60,000원으로 제한함.

# Output Format (JSON Only):
반드시 아래 JSON 형식으로만 응답하십시오. 설명은 배제합니다.
{{
    "keyword": "키워드명",
    "before_bid": 1000,
    "after_bid": 1150,
    "change_rate": "15%",
    "reason": "이유"
}}
"""

# 4. API 호출 및 결과 받기 (새로운 방식)
try:
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt,
        config=types.GenerateContentConfig(
            response_mime_type="application/json"  # JSON 강제 출력 설정
        )
    )
    
    # 결과 출력
    print("--- AI Agent 분석 결과 ---")
    print(response.text)
    
    # JSON 파싱 테스트
    #result_json = json.loads(response.text)
    #print(f"\n[System] 추천 액션: {result_json['action']}")

except Exception as e:
    print(f"에러 발생: {e}")
# Out:
# --- AI Agent 분석 결과 ---
# [
#   {
#     "keyword": "온라인명도소송",
#     "before_bid": 3000,
#     "after_bid": 3000,
#     "change_rate": "+0%",
#     "reason": "노출수 0: 현재가 유지"
#   },
#   {
#     "keyword": "사전명도소송",
#     "before_bid": 3000,
#     "after_bid": 3000,
#     "change_rate": "+0%",
#     "reason": "노출수 0: 현재가 유지"
#   },
#   {
#     "keyword": "법원명도소송",
#     "before_bid": 3000,
#     "after_bid": 3000,
#     "change_rate": "+0%",
#     "reason": "노출수 0: 현재가 유지"
#   },
#   {
#     "keyword": "법무사명도소송",
#     "before_bid": 14400,
#     "after_bid": 11520,
#     "change_rate": "-20%",
#     "reason": "ROAS 저효율: 20% 인하"
#   },
#   {
#     "keyword": "법도명도소송센터",
#     "before_bid": 3000,
#     "after_bid": 3000,
#     "change_rate": "+0%",
#     "reason": "노출수 0: 현재가 유지"
#   },
#   {
#     "keyword": "명도소송후기",
#     "before_bid": 14400,
#     "after_bid": 11520,
#     "change_rate": "-20%",
#     "reason": "ROAS 저효율: 20% 인하"
#   },
#   {
#     "keyword": "명도소송진행절차",
# ...
